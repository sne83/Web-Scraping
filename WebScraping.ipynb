# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=6e2ae66a2cfaf4176bfdb73b65787bcd&language=en-US&page=1')

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#       id                        title  \
# 0    278     The Shawshank Redemption
# 1    238                The Godfather
# 2    240        The Godfather Part II
# 3    424             Schindler's List
# 4  19404  Dilwale Dulhania Le Jayenge
#
#                                             overview release_date  popularity  \
# 0  Framed in the 1940s for the double murder of h...   1994-09-23     130.509
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     148.073
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      90.869
# 3  The true story of how businessman Oskar Schind...   1993-12-15      80.928
# 4  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      41.024
#
#    vote_average  vote_count
# 0         8.710       25339
# 1         8.707       19303
# 2         8.591       11642
# 3         8.572       15002
# 4         8.547        4318

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,455):
  response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=6e2ae66a2cfaf4176bfdb73b65787bcd&language=en-US&page={}'.format(i))
  temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
  df = df.append(temp_df, ignore_index=True)
# Out:
# <ipython-input-33-0f02f20cf519>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index=True)
# <ipython-input-33-0f02f20cf519>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index=True)
# <ipython-input-33-0f02f20cf519>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index=True)
# <ipython-input-33-0f02f20cf519>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index=True)
# ...

# %%
df.shape
# Out:
# (9080, 7)

# %%
df.to_csv('movies.csv')
